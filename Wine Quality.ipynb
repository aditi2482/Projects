# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/DSData/master/winequality-red.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# # EDA

# %% [markdown]
# Scatterplot:

# %%
import seaborn as sns
sns.scatterplot(x="fixed acidity",y="quality",data=df)
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='quality'>

# %%
import seaborn as sns
sns.scatterplot(x="volatile acidity",y="quality",data=df)
# Out:
# <AxesSubplot:xlabel='volatile acidity', ylabel='quality'>

# %%
import seaborn as sns
sns.scatterplot(x="citric acid",y="quality",data=df)
# Out:
# <AxesSubplot:xlabel='citric acid', ylabel='quality'>

# %%
import seaborn as sns
sns.scatterplot(x="residual sugar",y="quality",data=df)
# Out:
# <AxesSubplot:xlabel='residual sugar', ylabel='quality'>

# %%
import seaborn as sns
sns.scatterplot(x="chlorides",y="quality",data=df)
# Out:
# <AxesSubplot:xlabel='chlorides', ylabel='quality'>

# %%
import seaborn as sns
sns.scatterplot(x="sulphates",y="quality",data=df)
# Out:
# <AxesSubplot:xlabel='sulphates', ylabel='quality'>

# %%
import seaborn as sns
sns.scatterplot(x="alcohol",y="quality",data=df)
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='quality'>

# %%
import seaborn as sns
sns.scatterplot(x="density",y="quality",data=df)
# Out:
# <AxesSubplot:xlabel='density', ylabel='quality'>

# %%
import seaborn as sns
sns.scatterplot(x="pH",y="quality",data=df)
# Out:
# <AxesSubplot:xlabel='pH', ylabel='quality'>

# %%
import seaborn as sns
sns.scatterplot(x="free sulfur dioxide",y="quality",data=df)
# Out:
# <AxesSubplot:xlabel='free sulfur dioxide', ylabel='quality'>

# %%
import seaborn as sns
sns.scatterplot(x="total sulfur dioxide",y="quality",data=df)
# Out:
# <AxesSubplot:xlabel='total sulfur dioxide', ylabel='quality'>

# %% [markdown]
# # Correlation

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.114777   0.093705            -0.153794
# volatile acidity            0.001918   0.061298            -0.010504
# citric acid                 0.143577   0.203823            -0.060978
# residual sugar              1.000000   0.055610             0.187049
# chlorides                   0.055610   1.000000             0.005562
# free sulfur dioxide         0.187049   0.005562             1.000000
# total sulfur dioxide        0.203028   0.047400             0.667666
# density                     0.355283   0.200632            -0.021946
# pH                         -0.085652  -0.265026             0.070377
# sulphates                   0.005527   0.371260             0.051658
# alcohol                     0.042075  -0.221141            -0.069408
# quality                     0.013732  -0.128907            -0.050656
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.113181  0.668047 -0.682978   0.183006
# volatile acidity                  0.076470  0.022026  0.234937  -0.260987
# citric acid                       0.035533  0.364947 -0.541904   0.312770
# residual sugar                    0.203028  0.355283 -0.085652   0.005527
# chlorides                         0.047400  0.200632 -0.265026   0.371260
# free sulfur dioxide               0.667666 -0.021946  0.070377   0.051658
# total sulfur dioxide              1.000000  0.071269 -0.066495   0.042947
# density                           0.071269  1.000000 -0.341699   0.148506
# pH                               -0.066495 -0.341699  1.000000  -0.196648
# sulphates                         0.042947  0.148506 -0.196648   1.000000
# alcohol                          -0.205654 -0.496180  0.205633   0.093595
# quality                          -0.185100 -0.174919 -0.057731   0.251397
#
#                        alcohol   quality
# fixed acidity        -0.061668  0.124052
# volatile acidity     -0.202288 -0.390558
# citric acid           0.109903  0.226373
# residual sugar        0.042075  0.013732
# chlorides            -0.221141 -0.128907
# free sulfur dioxide  -0.069408 -0.050656
# total sulfur dioxide -0.205654 -0.185100
# density              -0.496180 -0.174919
# pH                    0.205633 -0.057731
# sulphates             0.093595  0.251397
# alcohol               1.000000  0.476166
# quality               0.476166  1.000000

# %%
df.corr()['quality'].sort_values()
# Out:
# volatile acidity       -0.390558
# total sulfur dioxide   -0.185100
# density                -0.174919
# chlorides              -0.128907
# pH                     -0.057731
# free sulfur dioxide    -0.050656
# residual sugar          0.013732
# fixed acidity           0.124052
# citric acid             0.226373
# sulphates               0.251397
# alcohol                 0.476166
# quality                 1.000000
# Name: quality, dtype: float64

# %% [markdown]
# Correlation using Heatmap:

# %%
import matplotlib.pyplot as plt
#size of canvas
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True,linewidths=0.5,linecolor="black",fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Describing Datasets:

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt="f")
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title("Variable Summary")
plt.show()

# %% [markdown]
# Outliers Checking:

# %%
collist=df.columns.values
ncol=30
nrows=14
plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='green',orient='h')
    plt.tight_layout()
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\lenovo\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\lenovo\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\lenovo\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\lenovo\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\lenovo\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\lenovo\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\lenovo\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\lenovo\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\lenovo\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\lenovo\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\lenovo\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Skewness

# %%
df.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# quality                 0.217802
# dtype: float64

# %% [markdown]
# # Normal Distribution Curve

# %%
sns.distplot(df["fixed acidity"])
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='fixed acidity', ylabel='Density'>

# %%
sns.distplot(df["volatile acidity"])
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='volatile acidity', ylabel='Density'>

# %%
sns.distplot(df["citric acid"])
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='citric acid', ylabel='Density'>

# %%
sns.distplot(df["residual sugar"])
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='residual sugar', ylabel='Density'>

# %%
sns.distplot(df["chlorides"])
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='chlorides', ylabel='Density'>

# %%
sns.distplot(df["free sulfur dioxide"])
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='free sulfur dioxide', ylabel='Density'>

# %%
sns.distplot(df["total sulfur dioxide"])
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total sulfur dioxide', ylabel='Density'>

# %%
sns.distplot(df["sulphates"])
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sulphates', ylabel='Density'>

# %%
sns.distplot(df["pH"])
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='pH', ylabel='Density'>

# %%
sns.distplot(df["alcohol"])
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='alcohol', ylabel='Density'>

# %% [markdown]
# # Data Cleaning:

# %%
df.corr()['quality']
# Out:
# fixed acidity           0.124052
# volatile acidity       -0.390558
# citric acid             0.226373
# residual sugar          0.013732
# chlorides              -0.128907
# free sulfur dioxide    -0.050656
# total sulfur dioxide   -0.185100
# density                -0.174919
# pH                     -0.057731
# sulphates               0.251397
# alcohol                 0.476166
# quality                 1.000000
# Name: quality, dtype: float64

# %%
delete=pd.DataFrame([["0.013732","residual sugar","No","Alot"],["-0.050656","free sulfur dioxide","No","Alot"],["-0.057731","pH","No","Alot"]],columns=["Correlation with Target","Column Name","Normalized","Outliers"])
delete
# Out:
#   Correlation with Target          Column Name Normalized Outliers
# 0                0.013732       residual sugar         No     Alot
# 1               -0.050656  free sulfur dioxide         No     Alot
# 2               -0.057731                   pH         No     Alot

# %%
df=df.drop(["residual sugar","free sulfur dioxide","pH"],axis=1)

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  chlorides  \
# 0               7.4             0.700         0.00      0.076
# 1               7.8             0.880         0.00      0.098
# 2               7.8             0.760         0.04      0.092
# 3              11.2             0.280         0.56      0.075
# 4               7.4             0.700         0.00      0.076
# ...             ...               ...          ...        ...
# 1594            6.2             0.600         0.08      0.090
# 1595            5.9             0.550         0.10      0.062
# 1596            6.3             0.510         0.13      0.076
# 1597            5.9             0.645         0.12      0.075
# 1598            6.0             0.310         0.47      0.067
#
#       total sulfur dioxide  density  sulphates  alcohol  quality
# 0                     34.0  0.99780       0.56      9.4        5
# 1                     67.0  0.99680       0.68      9.8        5
# 2                     54.0  0.99700       0.65      9.8        5
# 3                     60.0  0.99800       0.58      9.8        6
# 4                     34.0  0.99780       0.56      9.4        5
# ...                    ...      ...        ...      ...      ...
# 1594                  44.0  0.99490       0.58     10.5        5
# 1595                  51.0  0.99512       0.76     11.2        6
# 1596                  40.0  0.99574       0.75     11.0        6
# 1597                  44.0  0.99547       0.71     10.2        5
# 1598                  42.0  0.99549       0.66     11.0        6
#
# [1599 rows x 9 columns]

# %% [markdown]
# # Removing Outliers:

# %% [markdown]
# Z-Score Technique

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z.shape
# Out:
# (1599, 9)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  13,   15,   17,   17,   19,   38,   42,   43,   81,   81,   83,
#          86,   88,   91,   92,  106,  106,  109,  120,  126,  127,  142,
#         144,  147,  151,  151,  151,  169,  169,  181,  199,  226,  226,
#         240,  243,  244,  258,  258,  281,  291,  339,  340,  347,  354,
#         374,  381,  391,  442,  442,  451,  459,  467,  480,  515,  517,
#         544,  554,  554,  555,  555,  557,  557,  568,  588,  591,  608,
#         614,  636,  639,  649,  651,  652,  652,  672,  672,  684,  690,
#         690,  692,  692,  723,  724,  730,  754,  776,  777,  795,  821,
#         832,  836,  837,  889,  899, 1017, 1018, 1051, 1051, 1079, 1081,
#        1114, 1165, 1244, 1260, 1269, 1269, 1270, 1270, 1288, 1289, 1299,
#        1299, 1312, 1319, 1319, 1367, 1370, 1370, 1372, 1372, 1374, 1374,
#        1434, 1435, 1469, 1474, 1476, 1478, 1493, 1496, 1505, 1558, 1570],
#       dtype=int64), array([6, 4, 3, 6, 3, 1, 3, 6, 3, 6, 3, 6, 6, 6, 6, 3, 6, 4, 1, 1, 1, 7,
#        7, 3, 2, 3, 6, 3, 6, 3, 1, 3, 6, 3, 0, 0, 3, 6, 3, 3, 6, 6, 0, 4,
#        0, 0, 0, 0, 5, 3, 8, 7, 5, 4, 8, 0, 0, 5, 0, 5, 0, 5, 3, 7, 4, 5,
#        6, 4, 6, 4, 4, 0, 7, 1, 4, 4, 1, 8, 3, 6, 6, 1, 3, 3, 3, 3, 6, 7,
#        8, 5, 5, 5, 8, 5, 5, 3, 6, 4, 4, 5, 3, 4, 3, 5, 7, 5, 7, 6, 6, 1,
#        8, 1, 3, 6, 6, 3, 6, 3, 6, 3, 8, 5, 5, 8, 5, 5, 8, 4, 4, 8, 3, 3],
#       dtype=int64))

# %%
len(np.where(z>3)[0])
# Out:
# 132

# %%
z.iloc[4]
# Out:
# fixed acidity           0.528360
# volatile acidity        0.961877
# citric acid             1.391472
# chlorides               0.243707
# total sulfur dioxide    0.379133
# density                 0.558274
# sulphates               0.579207
# alcohol                 0.960246
# quality                 0.787823
# Name: 4, dtype: float64

# %%
df_new=df[(z<3).all(axis=1)]
print("Old Dataframe",df.shape)
print("New Dataframe",df_new.shape)
print("total_dropped_rows",df.shape[0]-df_new.shape[0])
# Out:
# Old Dataframe (1599, 9)
# New Dataframe (1491, 9)
# total_dropped_rows 108

# %% [markdown]
# # Percentage Data Loss:

# %%
loss_percent=(1599-1491)/1599*100
print(loss_percent,'%')
# Out:
# 6.75422138836773 %

# %% [markdown]
# Dividing data in features and vectors:

# %%
#independent column
x=df_new.iloc[:,:-1]
#target
y=df_new.iloc[:,-1]

# %% [markdown]
# # Transforming data to remove skewness:

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
x
# Out:
# array([[-0.4339833 ,  1.05161896, -1.52123322, ...,  0.62798219,
#         -0.57707756, -1.13254541],
#        [-0.14230933,  1.9321511 , -1.52123322, ...,  0.05634263,
#          0.46574739, -0.49800204],
#        [-0.14230933,  1.35767096, -1.23907712, ...,  0.17110204,
#          0.23671093, -0.49800204],
#        ...,
#        [-1.39982972, -0.01381763, -0.6552709 , ..., -0.55557083,
#          0.93553721,  0.75618484],
#        [-1.82562139,  0.75895896, -0.71694523, ..., -0.71240619,
#          0.67738516,  0.01135802],
#        [-1.71474748, -1.32923515,  1.08097918, ..., -0.70077546,
#          0.31511284,  0.75618484]])

# %%
pd.DataFrame(x).skew()
# Out:
# 0   -0.057685
# 1    0.019628
# 2    0.019784
# 3    0.010562
# 4   -0.001168
# 5   -0.006347
# 6   -0.038055
# 7   -0.004156
# dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[-0.43409554,  1.05159016, -1.52117976, ...,  0.62799459,
#         -0.57717397, -1.1302401 ],
#        [-0.14245101,  1.93176188, -1.52117976, ...,  0.05636615,
#          0.46563176, -0.50287884],
#        [-0.14245101,  1.35753321, -1.23905287, ...,  0.17112472,
#          0.23656398, -0.50287884],
#        ...,
#        [-1.39968984, -0.01365651, -0.65529289, ..., -0.5555561 ,
#          0.93553408,  0.75357174],
#        [-1.8253144 ,  0.75901501, -0.71696337, ..., -0.71239666,
#          0.67731292,  0.00435976],
#        [-1.71448672, -1.32936519,  1.08098821, ..., -0.70076551,
#          0.31497463,  0.75357174]])

# %%
pd.DataFrame(x).skew()
# Out:
# 0   -0.056953
# 1    0.018936
# 2    0.019890
# 3    0.022658
# 4   -0.001718
# 5   -0.006482
# 6   -0.037275
# 7    0.014173
# dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Splitting the dataframe:

# %%
for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    if round(accuracy_score(y_train,pred_train)*100,1) == round(accuracy_score(y_test,pred_test)*100,1):
        print("At random state",i,"the model performs very well")
        print("At random_state:-",i)
        print("Training accuracy_score is:-",accuracy_score(y_train,pred_train)*100)
        print("Testing accuracy_score is:-",accuracy_score(y_test,pred_test)*100,'\n')
# Out:
# At random state 31 the model performs very well
# At random_state:- 31
# Training accuracy_score is:- 61.241610738255034
# Testing accuracy_score is:- 61.20401337792642
#
# At random state 55 the model performs very well
# At random_state:- 55
# Training accuracy_score is:- 61.493288590604024
# Testing accuracy_score is:- 61.53846153846154
#
# At random state 225 the model performs very well
# At random_state:- 225
# Training accuracy_score is:- 61.241610738255034
# Testing accuracy_score is:- 61.20401337792642
#
# At random state 236 the model performs very well
# At random_state:- 236
# Training accuracy_score is:- 61.241610738255034
# Testing accuracy_score is:- 61.20401337792642
#
# At random state 295 the model performs very well
# At random_state:- 295
# Training accuracy_score is:- 61.91275167785235
# Testing accuracy_score is:- 61.87290969899666
#
# At random state 296 the model performs very well
# At random_state:- 296
# Training accuracy_score is:- 61.15771812080537
# Testing accuracy_score is:- 61.20401337792642
#
# At random state 468 the model performs very well
# At random_state:- 468
# Training accuracy_score is:- 61.15771812080537
# Testing accuracy_score is:- 61.20401337792642
#
# At random state 499 the model performs very well
# At random_state:- 499
# Training accuracy_score is:- 61.241610738255034
# Testing accuracy_score is:- 61.20401337792642
#
# At random state 694 the model performs very well
# At random_state:- 694
# Training accuracy_score is:- 61.241610738255034
# Testing accuracy_score is:- 61.20401337792642
#
# At random state 700 the model performs very well
# At random_state:- 700
# Training accuracy_score is:- 61.493288590604024
# Testing accuracy_score is:- 61.53846153846154
#
# At random state 856 the model performs very well
# At random_state:- 856
# Training accuracy_score is:- 61.15771812080537
# Testing accuracy_score is:- 61.20401337792642
#
# At random state 931 the model performs very well
# At random_state:- 931
# Training accuracy_score is:- 60.151006711409394
# Testing accuracy_score is:- 60.200668896321076

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=827)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00        12
#            5       0.51      0.55      0.53       127
#            6       0.42      0.53      0.47       112
#            7       0.14      0.07      0.09        46
#            8       0.00      0.00      0.00         2
#
#     accuracy                           0.44       299
#    macro avg       0.21      0.23      0.22       299
# weighted avg       0.40      0.44      0.41       299
# C:\Users\lenovo\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\lenovo\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\lenovo\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # Cross validation score for logistic regression:

# %%
pred_lr=lr.predict(x_test)
from sklearn.model_selection import cross_val_score
lss=accuracy_score(y_test,pred_lr)
for j in range(2,10):
    lsscore=cross_val_score(lr,x,y,cv=j)
    lsc=lsscore.mean()
    print("At cv:-",j)
    print("Cross validation score is:-",lsc*100)
    print("accuracy_score is:-",lss*100)
    print("\n")
# Out:
# At cv:- 2
# Cross validation score is:- 55.33314140741674
# accuracy_score is:- 63.21070234113713
#
#
# At cv:- 3
# Cross validation score is:- 58.752515090543255
# accuracy_score is:- 63.21070234113713
#
#
# At cv:- 4
# Cross validation score is:- 58.620708293695415
# accuracy_score is:- 63.21070234113713
#
#
# At cv:- 5
# Cross validation score is:- 59.02538663554129
# accuracy_score is:- 63.21070234113713
#
#
# At cv:- 6
# Cross validation score is:- 59.09309280131277
# accuracy_score is:- 63.21070234113713
#
#
# At cv:- 7
# Cross validation score is:- 58.88665325285043
# accuracy_score is:- 63.21070234113713
#
#
# At cv:- 8
# Cross validation score is:- 59.43160255304467
# accuracy_score is:- 63.21070234113713
#
#
# At cv:- 9
# Cross validation score is:- 58.62236826092248
# accuracy_score is:- 63.21070234113713

# %%
lsscore_selected=cross_val_score(lr,x,y,cv=6).mean()
print("The cv score is: ",lsscore_selected,"\nThe accuracy score is: ",lss)
# Out:
# The cv score is:  0.5909309280131277
# The accuracy score is:  0.6321070234113713

# %% [markdown]
# # The model with the outliers:

# %% [markdown]
# AUC ROC curve:

# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split

# generate two class dataset
X, y = make_classification(n_samples=1000, n_classes=2, n_features=20, random_state=27)

# split into train-test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=27)

# %%
# train models
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

# logistic regression
model1 = LogisticRegression()
# knn
model2 = KNeighborsClassifier(n_neighbors=4)

# fit model
model1.fit(X_train, y_train)
model2.fit(X_train, y_train)

# predict probabilities
pred_prob1 = model1.predict_proba(X_test)
pred_prob2 = model2.predict_proba(X_test)

# %%
from sklearn.metrics import roc_curve

# roc curve for models
fpr1, tpr1, thresh1 = roc_curve(y_test, pred_prob1[:,1], pos_label=1)
fpr2, tpr2, thresh2 = roc_curve(y_test, pred_prob2[:,1], pos_label=1)

# roc curve for tpr = fpr 
random_probs = [0 for i in range(len(y_test))]
p_fpr, p_tpr, _ = roc_curve(y_test, random_probs, pos_label=1)

# %%
from sklearn.metrics import roc_auc_score

# auc scores
auc_score1 = roc_auc_score(y_test, pred_prob1[:,1])
auc_score2 = roc_auc_score(y_test, pred_prob2[:,1])

print(auc_score1, auc_score2)
# Out:
# 0.9762374461979914 0.9233769727403157

# %%
# matplotlib
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# plot roc curves
plt.plot(fpr1, tpr1, linestyle='--',color='orange', label='Logistic Regression')
plt.plot(fpr2, tpr2, linestyle='--',color='green', label='KNN')
plt.plot(p_fpr, p_tpr, linestyle='--', color='blue')
# title
plt.title('ROC curve')
# x label
plt.xlabel('False Positive Rate')
# y label
plt.ylabel('True Positive rate')

plt.legend(loc='best')
plt.savefig('ROC',dpi=300)
plt.show();
